# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue May 12 00:51:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from pathlib import Path


CW_DIRECTORY_FIAP = ""
FIAP_PROJECT = "Tech-Challenge-FIAP-FASE3/"
CW_DIRECTORY = ""

# Referência ao Hugging Face (carrega direto do Hub):
# df = pd.read_parquet("hf://datasets/AKCIT/MedPT/data/train-00000-of-00001.parquet")

try:
    #import google.colab  # noqa: F401
    from google.colab import drive

    _em_colab = True
except ImportError:
    _em_colab = False

if _em_colab:
    drive.mount('/content/drive')
    CW_DIRECTORY_FIAP = "/content/drive/MyDrive/elber/#Cursos/##FIAP/"
else:
    CW_DIRECTORY_FIAP = "C:/WORKSPACES/workspace-PYTHON/"

CW_DIRECTORY = CW_DIRECTORY_FIAP + FIAP_PROJECT
print(CW_DIRECTORY)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3/

# %%
#Este é um magic command do IPython.
#Ele altera o diretório de trabalho atual para a sessão do kernel IPython.
#Qualquer código Python subsequente executado neste kernel será executado a partir do novo diretório.
#Esta é a forma que você geralmente quer usar para mudar de diretório para o seu código.
# %cd $CW_DIRECTORY
# !pip list > pip_collab_finetune_antes.txt
# Out:
# /content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.4/67.4 MB 40.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 45.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 42.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 155.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 54.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.0/428.0 kB 42.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 116.0 MB/s eta 0:00:00
# ...

# %%
#Executando o HELP, eu verifico se vai dar algum erro de PROCESSADOR
# !python tunning/02_finetune_lora.py --help
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# /content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3/tunning/02_finetune_lora.py:64: UserWarning: WARNING: Unsloth should be imported before [transformers, peft] to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel, is_bfloat16_supported
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# usage: 02_finetune_lora.py [-h] [--dataset-dir DATASET_DIR]
#                            [--base-model-name BASE_MODEL_NAME]
#                            [--checkpoint-dir CHECKPOINT_DIR]
#                            [--final-dir FINAL_DIR]
# ...

# %%
#Verificar se o torch tem CUDA:
#Se o resultado mostrar True, o script vai funcionar.
# !python -c "import torch; print(torch.__version__); print(torch.cuda.is_available())"
# %cd $CW_DIRECTORY
# !pip list > pip_collab_finetune.txt
# Out:
# 2.10.0+cu128
# True
# /content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3

# %%
#Execucao de teste
#!python tunning/02_finetune_lora.py --max-train-samples 512 --max-validation-samples 128
#!python tunning/02_finetune_lora.py --max-seq-length 2048 --num-train-epochs 3.0 --logging-steps 50 --save-steps 500
#!python -u tunning/02_finetune_lora.py --max-seq-length 2048 --num-train-epochs 3.0 --logging-steps 50 --save-steps 50 --eval-steps 200 --per-device-train-batch-size 2 --per-device-eval-batch-size 1
#!python -u tunning/02_finetune_lora.py --resume-from-checkpoint "/content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3/data/checkpoints/qwen2.5-3b-medpt-lora/checkpoint-350" --max-seq-length 2048 --num-train-epochs 3.0 --logging-steps 50 --save-steps 50 --eval-steps 200 --per-device-train-batch-size 2 --per-device-eval-batch-size 1
# !python -u tunning/02_finetune_lora.py --resume-from-checkpoint "/content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3/data/checkpoints/qwen2.5-3b-medpt-lora/checkpoint-2150" --max-seq-length 2048 --num-train-epochs 3.0 --logging-steps 50 --save-steps 50 --eval-steps 200 --per-device-train-batch-size 2 --per-device-eval-batch-size 1
# Out:
# Streaming output truncated to the last 5000 lines.
#  14% 4849/35162 [14:09<1:32:30,  5.46it/s]
#  14% 4850/35162 [14:09<1:28:06,  5.73it/s]
#  14% 4851/35162 [14:09<1:24:28,  5.98it/s]
#  14% 4852/35162 [14:09<1:27:18,  5.79it/s]
#  14% 4853/35162 [14:09<1:24:08,  6.00it/s]
#  14% 4854/35162 [14:09<1:22:16,  6.14it/s]
#  14% 4855/35162 [14:10<1:21:37,  6.19it/s]
#  14% 4856/35162 [14:10<1:23:21,  6.06it/s]
#  14% 4857/35162 [14:10<1:25:23,  5.91it/s]
#  14% 4858/35162 [14:10<1:23:24,  6.05it/s]
#  14% 4859/35162 [14:10<1:21:17,  6.21it/s]
#  14% 4860/35162 [14:10<1:20:31,  6.27it/s]
#  14% 4861/35162 [14:11<1:19:05,  6.39it/s]
#  14% 4862/35162 [14:11<1:18:48,  6.41it/s]
#  14% 4863/35162 [14:11<1:22:51,  6.09it/s]
#  14% 4864/35162 [14:11<1:25:44,  5.89it/s]
#  14% 4865/35162 [14:11<1:29:40,  5.63it/s]
#  14% 4866/35162 [14:11<1:26:34,  5.83it/s]
#  14% 4867/35162 [14:12<1:24:44,  5.96it/s]
#  14% 4868/35162 [14:12<1:22:25,  6.13it/s]
#  14% 4869/35162 [14:12<1:20:52,  6.24it/s]
# ...
