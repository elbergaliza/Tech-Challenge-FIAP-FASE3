# %%
from pathlib import Path


CW_DIRECTORY_FIAP = ""
FIAP_PROJECT = "Tech-Challenge-FIAP-FASE3/"
CW_DIRECTORY = ""

# Referência ao Hugging Face (carrega direto do Hub):
# df = pd.read_parquet("hf://datasets/AKCIT/MedPT/data/train-00000-of-00001.parquet")

try:
    #import google.colab  # noqa: F401
    from google.colab import drive

    _em_colab = True
except ImportError:
    _em_colab = False

if _em_colab:
    drive.mount('/content/drive')
    CW_DIRECTORY_FIAP = "/content/drive/MyDrive/elber/#Cursos/##FIAP/"
else:
    CW_DIRECTORY_FIAP = "C:/WORKSPACES/workspace-PYTHON/"

print(CW_DIRECTORY_FIAP)

# %%
# Este é um magic command do IPython.
# Ele altera o diretório de trabalho atual para a sessão do kernel IPython.
# Qualquer código Python subsequente executado neste kernel será executado a partir do novo diretório.
# Esta é a forma que você geralmente quer usar para mudar de diretório para o seu código.
# %cd $CW_DIRECTORY
# !pip list > pip_collab_analyze.txt

# %%
# Instala dependencias necessarias (datasets do Hugging Face).
# O script 01 usa apenas a lib `datasets` alem da stdlib.
# !pip install -q datasets

# %%
# Executando o HELP, eu verifico se vai dar algum erro de imports.
# !python tunning/01_analyze_dataset.py --help

# %%
# Executa a analise, limpeza e particionamento do dataset MedPT.
# Parametros default: seed=42, train=0.8, validation=0.1, test=0.1,
# min_answer_tokens=10, max_answer_tokens=1000.
# O parquet deve estar em data/train-00000-of-00001.parquet.
# !python tunning/01_analyze_dataset.py
