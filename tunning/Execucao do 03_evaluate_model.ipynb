# %%
from pathlib import Path


CW_DIRECTORY_FIAP = ""
FIAP_PROJECT = "Tech-Challenge-FIAP-FASE3/"
CW_DIRECTORY = ""

# Referência ao Hugging Face (carrega direto do Hub):
# df = pd.read_parquet("hf://datasets/AKCIT/MedPT/data/train-00000-of-00001.parquet")

try:
    #import google.colab  # noqa: F401
    from google.colab import drive

    _em_colab = True
except ImportError:
    _em_colab = False

if _em_colab:
    drive.mount('/content/drive')
    CW_DIRECTORY_FIAP = "/content/drive/MyDrive/elber/#Cursos/##FIAP/"
else:
    CW_DIRECTORY_FIAP = "C:/WORKSPACES/workspace-PYTHON/"

CW_DIRECTORY = CW_DIRECTORY_FIAP + FIAP_PROJECT
print(CW_DIRECTORY)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3/

# %%
# Este é um magic command do IPython.
# Ele altera o diretório de trabalho atual para a sessão do kernel IPython.
# Qualquer código Python subsequente executado neste kernel será executado a partir do novo diretório.
# Esta é a forma que você geralmente quer usar para mudar de diretório para o seu código.
# %cd $CW_DIRECTORY
# !pip list > pip_collab_evaluate.txt
# Out:
# /content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3

# %%
# Cobre torch/transformers/peft/bitsandbytes/datasets e bert-score (opcional em --compute-bertscore).
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.4/67.4 MB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 41.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 125.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.0/428.0 kB 41.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 122.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 128.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 124.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 25.5 MB/s eta 0:00:00

# %%
# Executando o HELP, eu verifico se vai dar algum erro de PROCESSADOR / imports.
# !python tunning/03_evaluate_model.py --help
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# usage: 03_evaluate_model.py [-h] [--dataset-dir DATASET_DIR]
#                             [--manifest-path MANIFEST_PATH]
#                             [--adapter-dir ADAPTER_DIR]
#                             [--base-model-name BASE_MODEL_NAME]
#                             [--output-dir OUTPUT_DIR]
#                             [--max-eval-samples MAX_EVAL_SAMPLES]
#                             [--max-new-tokens MAX_NEW_TOKENS]
#                             [--temperature TEMPERATURE] [--compute-bertscore]
#
# Avalia o modelo LoRA do projeto MedPT.
#
# options:
#   -h, --help            show this help message and exit
#   --dataset-dir DATASET_DIR
#                         Diretorio com o DatasetDict processado. Padrao:
#                         data/processed/medpt_qa.
#   --manifest-path MANIFEST_PATH
#                         Manifesto JSONL salvo no script 01. Padrao:
#                         data/processed/medpt_qa_manifest.jsonl.
#   --adapter-dir ADAPTER_DIR
#                         Diretorio do adapter final salvo pelo script 02.
#                         Padrao: pre-trained/qwen2.5-3b-medpt-lora.
#   --base-model-name BASE_MODEL_NAME
#                         Nome do modelo base. Padrao: Qwen/Qwen2.5-3B-Instruct.
#   --output-dir OUTPUT_DIR
#                         Diretorio para salvar predicoes e relatorios. Padrao:
#                         data/evaluation/qwen2.5-3b-medpt-lora.
#   --max-eval-samples MAX_EVAL_SAMPLES
#                         Numero maximo de exemplos de teste para geracao.
#                         Padrao: 200.
#   --max-new-tokens MAX_NEW_TOKENS
#                         Quantidade maxima de tokens gerados por exemplo.
#                         Padrao: 256.
#   --temperature TEMPERATURE
#                         Temperatura de geracao (greedy quando 0.0). Padrao:
#                         0.0.
#   --compute-bertscore   Calcula BERTScore se a biblioteca estiver disponivel.
#                         Padrao: False.

# %%
# Verificar se o torch tem CUDA:
# !python -c "import torch; print(torch.__version__); print(torch.cuda.is_available())"
# Se o resultado mostrar True, o script pode usar GPU na inferência.
# Out:
# 2.10.0+cu128
# True

# %%
# Avaliacao no split de teste (dataset + manifest do script 01; adapter do script 02).
# Ajuste --max-eval-samples, --adapter-dir, --dataset-dir e --output-dir conforme o seu Drive.
# Para metricas semanticas adicionais: acrescente --compute-bertscore (bert-score ja esta no requirements-finetune.txt).
#!python tunning/03_evaluate_model.py --max-eval-samples 128
# !python tunning/03_evaluate_model.py --adapter-dir data/checkpoints/qwen2.5-3b-medpt-lora/checkpoint-3750 --output-dir data/evaluation/checkpoint-3750
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# config.json: 100% 661/661 [00:00<00:00, 3.16MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors.index.json: 35.6kB [00:00, 87.7MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100% 6.17G/6.17G [00:50<00:00, 123MB/s]
# Fetching 2 files: 100% 2/2 [00:50<00:00, 25.18s/it]
# Download complete: 100% 6.17G/6.17G [00:50<00:00, 122MB/s]
# Loading weights: 100% 434/434 [00:19<00:00, 21.97it/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 924kB/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# {
#   "model": {
#     "adapter_dir": "data/checkpoints/qwen2.5-3b-medpt-lora/checkpoint-3750",
#     "base_model_name": "Qwen/Qwen2.5-3B-Instruct"
#   },
#   "dataset": {
#     "dataset_dir": "data/processed/medpt_qa",
#     "manifest_path": "data/processed/medpt_qa_manifest.jsonl",
#     "evaluated_samples": 200
#   },
#   "metrics": {
#     "token_f1_mean": 0.22511085163300049,
#     "rouge_l_mean": 0.14027838256951647,
#     "bertscore": {
#       "enabled": false,
#       "computed": false,
#       "reason": "flag_disabled"
#     }
#   },
#   "safety": {
#     "caution_rate": 0.025,
#     "overconfidence_rate": 0.0,
#     "high_risk_case_count": 10,
#     "high_risk_caution_coverage": 0.0
#   },
#   "slices": {
#     "question_type_rouge_l_mean": {
#       "Tratamento": 0.14092534502128296,
#       "Diagnóstico": 0.13611199184895703,
#       "Epidemiologia": 0.13722253256575093,
#       "Escolha de profissionais de saúde": 0.2266029755684928,
#       "Estilo de vida saudável": 0.05151124703584429
#     },
#     "question_length_rouge_l_mean": {
#       "short": 0.1517408655574166,
#       "long": 0.13619720435822788,
#       "medium": 0.13473208584750215
#     },
#     "condition_bucket_rouge_l_mean": {
#       "long_tail": 0.14273645760478,
#       "frequent": 0.14000526312115386
#     }
#   }
# }
#
# Relatorio salvo em: /content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3/data/evaluation/checkpoint-3750/evaluation_summary.json
# Predicoes salvas em: /content/drive/MyDrive/elber/#Cursos/##FIAP/Tech-Challenge-FIAP-FASE3/data/evaluation/checkpoint-3750/predictions.jsonl
